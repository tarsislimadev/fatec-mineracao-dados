# %%
# !python -m pip install pandas mlxtend
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.3 MB/s  0:00:00
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# Out:
# Iniciando a Mineração de Regras de Associação (Apriori)...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 print("Iniciando a Mineração de Regras de Associação (Apriori)...\n")
#       6 # 1. DISCRETIZAÇÃO
# ----> 7 df_regras = df_global[['Country Name', 'Pagamento_Total_Divida', 'Gasto_Social']].copy()
#       9 df_regras['Faixa_Divida'] = pd.qcut(df_regras['Pagamento_Total_Divida'], q=3, labels=['Dívida_Baixa', 'Dívida_Média', 'Dívida_Alta'])
#      10 df_regras['Faixa_Social'] = pd.qcut(df_regras['Gasto_Social'], q=3, labels=['Social_Baixo', 'Social_Médio', 'Social_Alto'])
#
# NameError: name 'df_global' is not defined
