# %% [markdown]
# # Mineração de Dados

# %%
# !python -m pip install --quiet pandas matplotlib
# Out:
#   WARNING: The scripts f2py and numpy-config are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://cetic.br/media/microdados/988/tic_domicilios_2025_individuos_base_de_microdados_v1.0.csv'
df = pd.read_csv(url, sep=';', encoding='latin-1')
df.head()
# Out:
#        QUEST  ID_DOMICILIO  ID_MORADOR  SEXO  IDADE  FAIXA_ETARIA  \
# 0  216909933         28504           1     1     22             2
# 1  216912043         28515           2     2     34             3
# 2  216912364         28501           1     1     21             2
# 3  216912365         28505           1     2     64             6
# 4  216912367         28510           1     1     69             6
#
#    GRAU_INSTRUCAO_1  ESTUD  APOSENT  PEA  ...  G5_AGREG  I1A_NENHUM  \
# 0                14      0        0    3  ...         1          99
# 1                17      1        0    1  ...         1          99
# 2                15      1        0    1  ...         1          99
# 3                10      0        1    5  ...         0           1
# 4                13      0        1    5  ...         0           1
#
#    J5_FAIXAS  J2_NENHUM  J3_AGREG  J3AB  C5_COB_AGREG  C5_COB_NENHUM  \
# 0          1         99         1     3             0              1
# ...
